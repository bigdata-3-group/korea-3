# %%
# %load_ext watermark
# %watermark -a mkjang -d -v
# Out:
# mkjang 2019-08-10
#
# CPython 3.7.3
# IPython 7.4.0

# %% [markdown]
# ============유해도 필터링 함수===========

# %%
import numpy as np
import pandas as pd
import json
import re


def AUTO_LABEL(dataset,dictionary):
    '''
    인풋으로 '비속어사전'(dictionary)과 '필터링할 파일'(dataset)을 사용하며
    파일은 경로명을 입력하여줍니다.
     
    그러면 이 함수는 해당 파일과 비속어사전을 매핑하여, 
    비속어사전에 있는 단어가 해당파일에 있는 경우에
    필터링된 파일(dataset)에 유해함 여부를 1로써 나타냅니다.
    
    이때 유해도를 나타내는 컬럼은 dataset에서 새로운 'filtered'에 나타나며
    filtered는 디폴트로 0 값을 갖고 있다가, 비속어 사전과 채팅의 데이터가 매핑되면
    유해도가 1로 변경됩니다.
      
    '''
# 1. 데이터 셋 불러오기
    datasets = pd.DataFrame()
    dump = pd.read_csv(dataset, engine='python')
    datasets = pd.concat([datasets, dump])
        
# 2. 비속어 사전 불러오기
    with open(dictionary,'r') as f:
        forbiddenword = json.load(f)
        list2=list(forbiddenword.values()) 
        dict=list2[0] 
        dict1="|".join(dict) 
        
# 3. filtered라는 컬럼을 데이터셋에 추가함. (디폴트0, 필터되어 유해하면 1로 변경)
    datasets['filtered']=0
    data = datasets.comment

# 4. 유해 여부 실질적으로 판단
    idx = [i for i,d in enumerate(data) if re.search(dict1, d)]   
    datasets.iloc[idx,-1] = 1
    return datasets
    #return datasets[datasets['filtered']==1]=>필터된거만 보고싶을때

# %%
AUTO_LABEL('labeled (1).csv','word-fobidden.json')
# Out:
#                           comment  url_id  label  filtered
# 0                    아 이거 웃기네 ㅋㅋㅋ      56      0         0
# 1                               슬      36      0         0
# 2                          32.3 ㄷ      17      0         0
# 3                           팬미팅이넹      56      1         0
# 4                     빠꾸가 없네 이 둠피      27      0         0
# 5                               오      76      0         0
# 6                         가붕아....      17      1         0
# 7                          주니어 공개      55      0         0
# 8                   이제 자원 슬슬 마를텐데      72      0         0
# 9                        모르면 맞아야지      59      0         0
# 10                      유통만 한거아님?      75      0         0
# 11                           ㅁ.뭐야      20      0         0
# 12              브베야 공장언제가냐 공장야방해라      32      1         0
# 13                   오늘 라이즈 한번 보자      14      0         0
# 14                           거기자나      52      0         0
# 15                그럼아저씨는목소리못듣나?궁금      55      0         0
# 16                          9검사?!      65      0         0
# 17                       결혼최고너무조아      14      0         0
# 18       ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ      18      0         0
# 19                         공 통통튄다      22      0         0
# 20                           아무거나      56      0         0
# 21                        3연벙 에반데      16      0         0
# 22                              ?      72      0         0
# 23                        ㅋㅋㅋㅋㅋㅋㅋ      17      0         0
# 24                        알리 개못하네      20      1         0
# 25           난이도가 높다 = 강팀이 아니면 진다      17      0         0
# 26                     ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ      17      0         0
# 27              유니크 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ      74      0         0
# 28                              ?      16      0         0
# 29                         탑코르키 각      16      0         0
# ...                           ...     ...    ...       ...
# 2970                            윽      56      0         0
# 2971           ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ      56      0         0
# 2972               ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ      72      0         0
# 2973                  씹된놈<<<<<<<<      65      1         0
# 2974                      롤체 끝낫어요      63      0         0
# 2975                        고증인데?      16      0         0
# 2976         ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ      14      0         0
# 2977                   가붕이는 체스로 가      11      1         0
# 2978                     난 어떡해 ㅋㅋ      11      0         0
# 2979                 엉지개!엉지개!엉지개!      20      0         0
# 2980                   쌈박질 너무 잘한다      11      0         0
# 2981                   퐁듀테란 ㅋㅋㅋㅋㅋ      72      0         0
# 2982                      천명쑤심 ㄷㄷ      17      0         0
# 2983                    ㅋㅋㅋㅋㅋㅋㅋㅋㅋ      63      0         0
# 2984           근대 레킹볼 기본적으로 피통이크네      22      0         0
# 2985                      아붕아 ㅠㅠㅠ      19      1         0
# 2986                  아플카 안한데 ㅡ.ㅡ      32      0         0
# 2987                    너 방송몇시간했냐      36      0         0
# 2988  ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ      16      0         0
# 2989                         신데렐라      13      0         0
# 2990                          검사다      65      0         0
# 2991                           메주      75      0         0
# 2992           돈만 받아 처먹을 줄 아늠 대머리      31      1         1
# 2993         <<<< 룰러 대신 큐베 들이미는사람      18      0         0
# 2994                            슬      38      0         0
# 2995                        럭스 킬초      11      0         0
# 2996                       노래 부른다      52      0         0
# 2997                        왤케 파래      16      0         0
# 2998                      그 눈 꽃..      17      0         0
# 2999                        안X 못O      14      0         0
#
# [3000 rows x 4 columns]
