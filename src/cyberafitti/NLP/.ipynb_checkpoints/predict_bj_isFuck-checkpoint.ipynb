# %%
# %load_ext watermark
# %watermark -a Chan -d -v -p numpy,pandas,konlpy,tensorflow
# Out:
# Chan 2019-08-09
#
# CPython 3.7.3
# IPython 7.6.1
#
# numpy 1.16.4
# pandas 0.24.2
# konlpy 0.5.1
# tensorflow 1.13.1

# %%
import numpy as np
import pandas as pd
from konlpy.tag import Okt
import tensorflow as tf
from tensorflow.python.keras.preprocessing import sequence
from tensorflow import keras
from tqdm import tqdm
from collections import Counter
import pickle

# %%
# 각 동영상별로 count해야한다. 일단 dump파일로 짜놓기

# %%
dump_data = pd.read_csv("../../data/sample (7).csv", engine='python',names=['chat', 'label'])

# %%
dump_data.head()
# Out:
#                                                 chat  label
# 0  님, 50000원 후원 그라샤! - 브베야 오늘 이것만 주고 간다. 그리고 춤좀 그...      0
# 1                                               어켜졌당      0
# 2                                                브베형      0
# 3                                                 아니      0
# 4                                    싹둑이 채팅창 관리 중입니다      0

# %%
len(dump_data)
# Out:
# 500

# %%
morp = Okt()
morped = [morp.morphs(_, norm=True, stem=True) for _ in tqdm(dump_data.chat)]
# Out:
#   0%|                                                                                          | 0/500 [00:00<?, ?it/s]
#   0%|▏                                                                               | 1/500 [00:12<1:40:54, 12.13s/it]
#   1%|▍                                                                               | 3/500 [00:12<1:10:29,  8.51s/it]
#   1%|▊                                                                                 | 5/500 [00:12<49:16,  5.97s/it]
#   2%|█▍                                                                                | 9/500 [00:12<34:17,  4.19s/it]
#   2%|█▊                                                                               | 11/500 [00:12<24:06,  2.96s/it]
#   3%|██                                                                               | 13/500 [00:12<16:57,  2.09s/it]
#   3%|██▊                                                                              | 17/500 [00:13<11:55,  1.48s/it]
#   4%|███                                                                              | 19/500 [00:13<08:26,  1.05s/it]
#   5%|███▋                                                                             | 23/500 [00:13<05:56,  1.34it/s]
#   6%|████▊                                                                            | 30/500 [00:13<04:07,  1.90it/s]
#   7%|█████▌                                                                           | 34/500 [00:13<02:56,  2.63it/s]
#   9%|██████▉                                                                          | 43/500 [00:13<02:04,  3.68it/s]
#  11%|████████▉                                                                        | 55/500 [00:13<01:25,  5.18it/s]
#  14%|███████████                                                                      | 68/500 [00:13<00:59,  7.26it/s]
#  16%|████████████▋                                                                    | 78/500 [00:14<00:42, 10.04it/s]
#  17%|██████████████                                                                   | 87/500 [00:14<00:30, 13.56it/s]
#  19%|███████████████▍                                                                 | 95/500 [00:14<00:22, 17.93it/s]
#  21%|████████████████▉                                                               | 106/500 [00:14<00:16, 23.91it/s]
#  24%|███████████████████▏                                                            | 120/500 [00:14<00:11, 31.81it/s]
#  26%|████████████████████▉                                                           | 131/500 [00:14<00:09, 40.39it/s]
#  29%|███████████████████████▏                                                        | 145/500 [00:14<00:06, 50.74it/s]
#  31%|█████████████████████████                                                       | 157/500 [00:14<00:06, 55.73it/s]
#  34%|██████████████████████████▉                                                     | 168/500 [00:14<00:05, 65.30it/s]
#  37%|█████████████████████████████▎                                                  | 183/500 [00:15<00:04, 78.50it/s]
#  41%|████████████████████████████████▍                                               | 203/500 [00:15<00:03, 95.73it/s]
#  44%|██████████████████████████████████▍                                            | 218/500 [00:15<00:02, 102.98it/s]
#  51%|████████████████████████████████████████▍                                      | 256/500 [00:15<00:01, 130.59it/s]
#  55%|███████████████████████████████████████████▌                                   | 276/500 [00:15<00:01, 145.47it/s]
#  59%|██████████████████████████████████████████████▊                                | 296/500 [00:15<00:01, 146.29it/s]
#  63%|█████████████████████████████████████████████████▊                             | 315/500 [00:15<00:01, 139.51it/s]
#  69%|██████████████████████████████████████████████████████▎                        | 344/500 [00:15<00:00, 164.69it/s]
#  75%|███████████████████████████████████████████████████████████▌                   | 377/500 [00:15<00:00, 193.15it/s]
#  80%|████████████████████████████████████████████████████████████████▏               | 401/500 [00:16<00:01, 61.81it/s]
#  84%|███████████████████████████████████████████████████████████████████             | 419/500 [00:17<00:01, 76.29it/s]
#  87%|█████████████████████████████████████████████████████████████████████▉          | 437/500 [00:17<00:00, 88.18it/s]
#  91%|████████████████████████████████████████████████████████████████████████▋       | 454/500 [00:17<00:00, 99.80it/s]
#  95%|███████████████████████████████████████████████████████████████████████████    | 475/500 [00:17<00:00, 116.10it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████▋| 498/500 [00:17<00:00, 134.23it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 500/500 [00:17<00:00, 28.52it/s]

# %%
morped
# Out:
# [['님',
#   ',',
#   '50000원',
#   '후원',
#   '그라샤',
#   '!',
#   '-',
#   '브베',
#   '야',
#   '오늘',
#   '이',
#   '것',
#   '만',
#   '주다',
#   '간다',
#   '.',
#   '그리고',
#   '춤좀',
#   '그만',
#   '추다',
#   '땅',
#   '꺼지다'],
#  ['어', '켜지다'],
#  ['브베', '형'],
#  ['아니다'],
#  ['싹둑', '이', '채팅', '창', '관리', '중', '이다'],
#  ['왜', '또', '늦었샤', 'ㅡㅡ'],
#  ['?!????', '???'],
#  ['왜캐늦게왓샤'],
#  ['싹둑', '이', '채팅', '창', '관리', '중', '이다'],
#  ['야',
#   '브베',
#   '야',
#   '너',
#   '난리',
#   '나다',
#   '어제',
#   '일',
#   '때문',
#   '에',
#   '기자',
#   '들',
#   '이',
#   '너',
#   '찾다',
#   '~'],
#  ['브베', '미애', '장례식', '치르다', '오다'],
#  ['케', '_', '인', '부터', '해명', '하고', '하자'],
#  ['타', '스트리머', '비다', '신', '낫', '네'],
#  ['나', '팔로우', '햇샤'],
#  ['SabaPing'],
#  ['미치다', '새', 'ㅡ', '끼'],
#  ['싹둑', '이', '채팅', '창', '관리', '중', '이다'],
#  ['지금', '이', '노래', '부르다', '상황', '이냐', '?'],
#  ['냔냔냔'],
#  ['쁘뼤', '야', '땨댱해', '창슥', '아'],
#  ['오늘', '기분', '도', '안좋다', '브베', '방송', '이나', '보고', '풀다'],
#  ['시작', '부터', '도우넛', '미치다'],
#  ['어제', '아무렇다', '이유', '없이', '너', '한테', '욕먹다', '거', '기분', '이', '나쁘다'],
#  ['ㄲ'],
#  ['얘', '들', '아', '오늘', '도', '잘', '부다', '탁하다', '.'],
#  ['싹둑', '이', '채팅', '창', '관리', '중', '이다'],
#  ['오빠', '옷', '왜안', '갈아입다', '샤', '?'],
#  ['해명', '하다'],
#  ['대답', '도', '안', '해주다', '샤', 'ㅠㅠ'],
#  ['해명', '부터'],
#  ['싹둑', '이', '채팅', '창', '관리', '중', '이다'],
#  ['옥', '슬', '아'],
#  ['브베', '브베', '뼤베벱쁘베브베뻬', '베', '베다'],
#  ['브베', '브베'],
#  ['베베', '베'],
#  ['자살', '유도', '노래', '임'],
#  ['님', '이', '10,000원', '후원', '그라샤', '!', '-', '미띵넘'],
#  ['나이', '치다', '먹다', '왜', '그렇게', '노', '냐', '브베', '야'],
#  ['렉', '개다', '짐'],
#  ['ㅋㅋㅋ'],
#  ['야'],
#  ['너', '때메', '케', '2', '인', '방송', '진행', '안되다', '신나다'],
#  ['남',
#   '과거',
#   '들추다',
#   '자기',
#   '과거',
#   '는',
#   '들추다',
#   '싫어하다',
#   '그게',
#   '뭐',
#   '냐',
#   '해명',
#   '하다',
#   '라남',
#   '과거',
#   '들추다',
#   '자기',
#   '과거',
#   '는',
#   '들추다',
#   '싫어하다',
#   '그게',
#   '뭐',
#   '냐',
#   '해명',
#   '하다',
#   '라남',
#   '과거',
#   '들추다',
#   '자기',
#   '과거',
#   '는',
#   '들추다',
#   '싫어하다',
#   '그게',
#   '뭐',
#   '냐',
#   '해명',
#   '하다',
#   '라남',
#   '과거',
#   '들추다',
#   '자기',
#   '과거',
#   '는',
#   '들추다',
#   '싫어하다',
#   '그게',
#   '뭐',
#   '냐',
#   '해명',
#   '하다'],
#  ['오빠', '안녕'],
#  ['브베', '야', '오늘', '은', '200만', '후원', '가다', '넌', '하다', '따다'],
#  ['싹둑', '이', '채팅', '창', '관리', '중', '이다'],
#  ['케'],
#  ['브베', '오만원', '받다', '/'],
#  ['인'],
#  ['?'],
#  ['안', '냥', '~~~'],
#  ['케이'],
#  ['케'],
#  ['인'],
#  ['브베', '형', '안녕하다', '저', '뽀뽀', '좀', '해주다', 'ㅎㅎㅎ'],
#  ['케'],
#  ['브베', '오빠', '안녕'],
#  ['인'],
#  ['케'],
#  ['인'],
#  ['미띵넘', '해주다'],
#  ['ㅅ', 'ㅂ', '맨날', '늦다'],
#  ['브베', '야', '오늘', '은', '200만', '후원', '가다', '넌', '하다', '대다', '댐'],
#  ['케'],
#  ['도', '2', '네', '하다'],
#  ['치킨', '먹다'],
#  ['딩가딩', '한테', '안', '냥', '~~', '인사', '해주다'],
#  ['디러'],
#  ['ㅎㅎㅎ'],
#  ['브베', '형', '띵하다'],
#  ['정신', '피', '폐해', '지네', 'ㄹㅇ'],
#  ['나', '는', '왜', '인사', '안해', '주다'],
#  ['또', '지각', '이냐'],
#  ['이노', '메', '방송', '을', '때리다', '가하다', '!'],
#  ['오늘', '왜', '늦었샤'],
#  ['한', '두보', '니', '아니다'],
#  ['일베', '딱', '반갑다'],
#  ['안녕하다', '.', '뽀뽀', '해주다', '.'],
#  ['어', '?', '견찰', '서', '갈라고', '지각', '하다'],
#  ['브베', '양', '딩기', '당', '한테', '안', '냥', '~~', '인사', '해주다'],
#  ['싹둑', '이', '채팅', '창', '관리', '중', '이다'],
#  ['옷', '똑같다', '거', '네', '맨날'],
#  ['브베', '야', '인사', '해주다'],
#  ['싹둑', '이', '채팅', '창', '관리', '중', '이다'],
#  ['싹둑', '이', '채팅', '창', '관리', '중', '이다'],
#  ['브베', '병띤', '샊', '이'],
#  ['브베', '오빠', '나다', '인사', '해주다'],
#  ['옷', '에서', '냄새', '안나', '냐', '씨', '1', '발련', '아'],
#  ['자세', '잡다', '보다'],
#  ['이',
#   '새',
#   '기',
#   '후원',
#   '으로',
#   '욕',
#   '하다',
#   '속',
#   '으로',
#   '좋아하다',
#   '그',
#   '돈',
#   '으로',
#   '안뫄방',
#   '간다'],
#  ['브거', '만'],
#  ['싹둑', '이', '채팅', '창', '관리', '중', '이다'],
#  ['바쁘다', 'ㅋㅋ'],
#  ['웩'],
#  [',.?'],
#  ['오늘', '은', '뭐', '들다', '샤', '~'],
#  ['오늘', '도', '대다', '각', '잡다', '가요', '?'],
#  ['인사', '해주다'],
#  ['ㅋㅋㅋ', '바쁘다', '?'],
#  ['OSkomodo'],
#  ['ㅋㅋㅋ'],
#  ['오빠', '나다', '인사', '해주다', '빨리'],
#  ['또', '뭘', '햇낄레', '씨발', '놈', '아'],
#  ['브루', 'ㅔ', '킥'],
#  ['옷', '보다', '모자', '가', '더불다', '쌍'],
#  ['밥', '치다', '먹다', '시간', '을', '줄이다', '충분하다', '옷', '갈아입다'],
#  ['니', '가', '빌게이츠', '냐', '시', ',', '바라다'],
#  ['브베', '야', '“', 'snowjeon', '2', '그라샤', '!!!', '”', '한번', '만', '해주다'],
#  ['표정', '왜', '이래', '요'],
#  ['논리', '개뿔', '도', '없다', '십샤끼', '가'],
#  ['브베', '야', '인사', '해주다', '샤'],
#  ['브베', '형', '안녕'],
#  ['옷', '갈아입다', '방송', '하다', '오늘'],
#  ['오늘', '은', '얼마', '가', '목포', '야'],
#  ['OSfrog'],
#  ['모자', '원래', '하얀색', '인데', '누렇', '게', '된거', 'ㄹㅇ', '?'],
#  ['형', '인사', '좀', '받다'],
#  ['아', '존나', '웃기', '네', 'ㅋ'],
#  ['표정', '이', '왜', '이리', '심각하다', 'ㅡㅡ'],
#  ['안녕하다', '.'],
#  ['나다', '인사', '해주다', 'ㅡㅡ'],
#  ['옥', '뜨다'],
#  ['브베', '아', '제', '안녕', '...'],
#  ['형', '새롭다', '찍다', '비트', '인가요', '?'],
#  ['심각하다', '척', '도', '.', '네', '땡기다', '수', '작', '부리', '네'],
#  ['형', '인사', '45', '번', '째', '야', '인사', '좀', '받다'],
#  ['아', '입다'],
#  ['고소', '밉다', '이다'],
#  ['고소', '밉다', '먹다', '야하다'],
#  ['어제', '시청자', '한테', '욕', '하다', '속이다', '쉬', '원하다'],
#  ['야'],
#  ['나다', '인', '.', '사', '.', '해', '.', '주다'],
#  ['인사', '해달라다', '영어', '못', '읽다', '스노우', '전이', '라고', '읽다'],
#  ['브베', '또', '빡치다', '?'],
#  ['ㅋㅋㅋ'],
#  ['닉네임', '어캐', '설정', '하다', '이', '거', '..'],
#  ['형', '인사', '좀', '받다', '46', '번', '째', '야'],
#  ['딩가딩', '한테', '안', '냥', '~', '인사', '해주다'],
#  ['브베', '형', '안낭'],
#  ['브라', '보릴', '베'],
#  ['표정', '이', '왜', '그', '따다', '?'],
#  ['뭔', '이상하다', '브금', '이야'],
#  ['님', '의', '귓속말', ':', '안녕'],
#  ['싹둑', '이', '채팅', '창', '관리', '중', '이다'],
#  ['싹둑', '이', '채팅', '창', '관리', '중', '이다'],
#  ['방금', '쫄은거봐', 'ㅋㅋ'],
#  ['얘또', '지', '각', '햇', '냐', '?'],
#  ['ㅁㅊㄴ', '마'],
#  ['ㄱㅅㄲ', '야'],
#  ['브베', '형', '따다', '행'],
#  ['방송', '키', '고', '혼자', '딴', '짓', '하고', '잇다'],
#  ['싹둑', '이', '채팅', '창', '관리', '중', '이다'],
#  ['벌써', '부터', '시청자', '겁박'],
#  ['부벵벵', '꼬미왔샤'],
#  ['왜', '잘', '못', '누르다', 'ㄱㅅㄱㅇ'],
#  ['형',
#   '부탁',
#   '인데',
#   '47',
#   '번',
#   '째',
#   '야',
#   '인사',
#   '좀',
#   '받다',
#   '진짜',
#   '개',
#   '빡치다',
#   '그렇다',
#   '받다'],
#  ['오늘', '도', '가만히', '앉다', '돈', '받다', '먹다'],
#  ['표정', '이', '왜', '그렇다', '좀', '웃다', '이', '새', '꺄'],
#  ['어제', '대다', '함', '?'],
#  ['상황', '의', '아이러니', '함', '을', '얘기', '하다', '브베', 'ㅎㅇ'],
#  ['힘들다'],
#  ['FUNgineer'],
#  ['어제', '대다', '한', '거', '보다', '브', '베스트', '가다'],
#  ['오늘', '왜', '입', '이', '튀어나오다', '?'],
#  ['싹둑', '이', '채팅', '창', '관리', '중', '이다'],
#  ['오늘', '은', '밥상', '안', '다지다', '오다', '겜방', '하', '는', '거', '맞다', '?'],
#  ['싹둑', '이', '채팅', '창', '관리', '중', '이다'],
#  ['브베', '아프리카', '떠나다', '??'],
#  ['싹둑', '이', '채팅', '창', '관리', '중', '이다'],
#  ['방송', '방금', '킨거', '알다', '?', '표정', '이', '썩다', '?'],
#  ['브베',
#   '형',
#   '지금',
#   '48',
#   '번',
#   '째',
#   '야',
#   '인사',
#   '좀',
#   '받다',
#   '진짜',
#   '키',
#   '보드',
#   '부쉬',
#   '고',
#   '싶다',
#   '빨리',
#   '받다'],
#  ['ㅡ'],
#  ['무슨', '일', '있샤', '?', '분위기', '가안', '죠', '앙'],
#  ['지다', '기분', '이', '왜', '나쁘다', '케', '-', '인니', '뮤', '가', '더', '기분', '나쁘다'],
#  ['ㅋㅋ'],
#  ['Chinese', '?'],
#  ['브베', '야', '10만원', '주면', '모자', '벗다', '?'],
#  ['네', '다', '짱'],
#  ['브베', '야'],
#  ['돈때메', '아프리카', '떠나다', '??'],
#  ['?'],
#  ['싹둑', '이', '채팅', '창', '관리', '중', '이다'],
#  ['싹둑', '이', '채팅', '창', '관리', '중', '이다'],
#  ['no', 'ROK'],
#  ['어제', '일', '얘기', '하다'],
#  ['어제', '대', 'ㅡ', '노함', '?'],
#  ['어제', '대', 'ㅡ', '노햇음', '?'],
#  ['브베', '야', '왜', '캐다'],
#  ['싹둑', '이', '채팅', '창', '관리', '중', '이다'],
#  ['어제', '욕', '한', '거', '사과', '하다'],
#  ['케', 'イン'],
#  ['대다', 'ㅡ', '노', '해보다', 'ㅋㅋ'],
#  ['어제', '는', '이미', '브베', '의', '머릿속', '에서', '없다', '일', '취급', 'ㅋㅋㅋ'],
#  ['싹둑', '이', '채팅', '창', '관리', '중', '이다'],
#  ['브베', '어제', '욕', '한', '거', '사과', '하다'],
#  ['사과', '하다'],
#  ['싹둑', '이', '채팅', '창', '관리', '중', '이다'],
#  ['ㅓ'],
#  ['어제', '욕', '한', '거', '사과', '하다', '어서'],
#  ['싹둑', '이', '채팅', '창', '관리', '중', '이다'],
#  ['자기', '잘못', '인거', '알', '면', '중', '고딩', '도', '먼저', '사과', '하', '는', '걸다'],
#  ['싹둑', '이', '채팅', '창', '관리', '중', '이다'],
#  ['싹둑', '이', '채팅', '창', '관리', '중', '이다'],
#  ['어제', '어글', '아직도', '가다', '?', '개인', '적', '으로', '사과', '하다', '그만하다', '칭구들앙'],
#  ['케읍', '이', '뭔', '데', '요', '무슨', '사건', '있다', '엇음', '?'],
#  ['gksrb',
#   '5496',
#   '님',
#   ',',
#   '1,000원',
#   '그라샤',
#   '!',
#   '-',
#   '브베',
#   '님',
#   '브',
#   '베스트',
#   '방송',
#   '보고',
#   '오다',
#   '.',
#   '항상',
#   '웃음',
#   '을',
#   '잃다',
#   '않다',
#   '브베',
#   '님',
#   '모습',
#   '을',
#   '보고',
#   '저',
#   '도',
#   '희망',
#   '을',
#   '잃다',
#   '않다',
#   '살아가다',
#   '있다',
#   '항상',
#   '힘내다'],
#  ['이', '거', '표절', '한', '거', '같다'],
#  ['도넛', '작작'],
#  ['사'],
#  ['과'],
#  ['브금', '표절', '함', '?'],
#  ['사'],
#  ['?'],
#  ['?'],
#  ['ㅋㅋㅋ'],
#  ['과'],
#  ['브베', '형', '안녕하다', '기', '환', '이', '오다'],
#  ['??'],
#  ['사'],
#  ['왜', '끌다', 'ㄱㅅㄲ', '야'],
#  ['?'],
#  ['???'],
#  ['??'],
#  ['과'],
#  ['케케켕잉'],
#  ['싹둑', '이', '채팅', '창', '관리', '중', '이다'],
#  ['싹둑', '이', '채팅', '창', '관리', '중', '이다'],
#  ['ㄱㅅㄲ', '야'],
#  ['사'],
#  ['과'],
#  ['실화', '냐'],
#  ['검열', 'ㅁㅊ'],
#  ['싹둑', '이', '채팅', '창', '관리', '중', '이다'],
#  ['ㅋㅋㅋ'],
#  ['롼'],
#  ['?'],
#  ['불'],
#  ['븝', '!!!!!!'],
#  ['싹둑', '이', '채팅', '창', '관리', '중', '이다'],
#  ['ㅡㅡ', '뭐', '야', '쑤다', '이발'],
#  ['사과', '하다'],
#  ['이',
#   '새',
#   '기',
#   '후원',
#   '으로',
#   '욕',
#   '하다',
#   '속',
#   '으로',
#   '좋아하다',
#   '그',
#   '돈',
#   '으로',
#   '안뫄방',
#   '간다',
#   'ㆍ'],
#  ['환'],
#  ['싹둑', '이', '채팅', '창', '관리', '중', '이다'],
#  ['아예', '전자', '계집', '스킵', '하', '네', 'ㅋㅋㅋ', '대놓고', '호구', '취급'],
#  ['쟤', '지금', '뭐', '하다'],
#  ['불'],
#  ['싹둑', '이', '채팅', '창', '관리', '중', '이다'],
#  ['옥'],
#  ['슬'],
#  ['싹둑', '이', '채팅', '창', '관리', '중', '이다'],
#  ['븝', '...'],
#  ['환'],
#  ['쓰다'],
#  ['씨팔', '룐'],
#  ['싹둑', '이', '채팅', '창', '관리', '중', '이다'],
#  ['쏘다'],
#  ['싹둑', '이', '채팅', '창', '관리', '중', '이다'],
#  ['이렇다', '쏘다'],
#  ['ㄴㅈ'],
#  ['팬', '도', '안티', '로', '만들다', '버리다', '능력', '귯걸'],
#  ['싹둑', '이', '채팅', '창', '관리', '중', '이다'],
#  ['개', '노잼'],
#  ['ㄵ'],
#  ['ㄴㅈ'],
#  ['왜', '이제', '왰어', '?'],
#  ['싹둑', '이', '채팅', '창', '관리', '중', '이다'],
#  ['싹둑', '이', '채팅', '창', '관리', '중', '이다'],
#  ['싹둑', '이', '채팅', '창', '관리', '중', '이다'],
#  ['ㅋㅋㅋ', '아', 'ㅈㄴ', '웃기', '네', 'ㅋㅋㅋ'],
#  ['싹둑', '이', '채팅', '창', '관리', '중', '이다'],
#  ['쟤',
#   '를',
#   '보고',
#   '희망',
#   '을',
#   '느끼다',
#   '정도',
#   '면',
#   '얼마나',
#   '절체절명',
#   '의',
#   '상황',
#   '에',
#   '직면',
#   '한',
#   '거',
#   '냐'],
#  ['옥', '쓰리다'],
#  ['싹둑', '이', '채팅', '창', '관리', '중', '이다'],
#  ['좀', '읽다', 'ㅇ', '씨발', '년', '아'],
#  ['옥', '쓸다'],
#  ['싹둑', '이', '채팅', '창', '관리', '중', '이다'],
#  ['요술', '가루', '뿌리다'],
#  ['딩동댕동'],
#  ['사과', '하다', '그게', '힘들다', '?'],
#  ['싹둑', '이', '채팅', '창', '관리', '중', '이다'],
#  ['어제', '뭐', '인데'],
#  ['채팅', '좀', '보다', '개또', '라이', '같다', '새끼', '야'],
#  ['싹둑', '이', '채팅', '창', '관리', '중', '이다'],
#  ['브베',
#   '어제',
#   '일',
#   '요약',
#   '-',
#   '케',
#   '=',
#   '인',
#   '저격',
#   ',',
#   '시청자',
#   '욕함',
#   ',',
#   '도넛',
#   '안',
#   '터지다',
#   '분발',
#   '하',
#   '라고',
#   '욕함'],
#  ['싹둑', '이', '채팅', '창', '관리', '중', '이다'],
#  ['싹둑', '이', '채팅', '창', '관리', '중', '이다'],
#  ['내', '가', '재밌다', '이야기', '하나', '해', '줄', '게'],
#  ['기분', '이', '왜', '안좋다', '보이', '샤'],
#  ['싹둑', '이', '채팅', '창', '관리', '중', '이다'],
#  ['문제', '있다'],
#  ['싹둑', '이', '채팅', '창', '관리', '중', '이다'],
#  ['싹둑', '이', '=', '브베', '미애', '=', '브베'],
#  ['표정', '존', 'ㄴ', '나', '벌레', '씹다', '같다', 'ㅋㅋ'],
#  ['케'],
#  ['너', '부터', '목', '매달', '면', '되다'],
#  ['싹둑', '이', '채팅', '창', '관리', '중', '이다'],
#  ['예전', '에', '백', '애', '따다', '비제', '이', '가', '있읐어'],
#  ['해명', '하다', 'ㅆㅂ', '하루', '지나다', '없다', '일', '되다', '임', '?'],
#  ['싹둑', '이', '채팅', '창', '관리', '중', '이다'],
#  ['방송', '꺼', '라', '시', '이', '발아'],
#  ['모르다', '물어보다'],
#  ['어제', '...', '엄청나다', '...'],
#  ['난', '누구', '라고', '이야기', '안함'],
#  ['트위치', '는', '게임', '하다', '방송', '아니다', '??'],
#  ['케'],
#  ['케'],
#  ['역사', '를', '잊다', '국민', '에게', '미래', '는', '없다'],
#  ['브베',
#   '님',
#   '안녕하다',
#   '저',
#   '는',
#   '브베',
#   '님',
#   '의',
#   '유투브',
#   '롤',
#   '보고',
#   '알',
#   '게',
#   '되다',
#   '하다',
#   '시청자',
#   '이다',
#   '브베',
#   '님',
#   '의',
#   '사이킥',
#   '한',
#   '음악',
#   '과',
#   '라이프',
#   '스타일',
#   '방송',
#   '을',
#   '너무',
#   '잘',
#   '보다',
#   '있다',
#   '.',
#   '그걸',
#   '보고',
#   '저',
#   '는',
#   '매일',
#   '힘',
#   '을',
#   '내다',
#   '열심히',
#   '살아가다',
#   '.',
#   '정말',
#   '감사하다',
#   '.',
#   '급식',
#   '충',
#   '들',
#   '이',
#   '너무',
#   '뭐라다',
#   '해도',
#   '너무',
#   '신경',
#   '쓰다',
#   '말다',
#   '쇼',
#   '정말',
#   '좋다',
#   '신분',
#   '인데',
#   '못',
#   '알아보다',
#   '너무',
#   '불쌍하다',
#   '.',
#   '화이팅',
#   '하다',
#   '쇼'],
#  ['싹둑', '이', '채팅', '창', '관리', '중', '이다'],
#  ['배고프다', '시바'],
#  ['케'],
#  ['인'],
#  ['인'],
#  ['인'],
#  ['하루',
#   '지나다',
#   '없다',
#   '일',
#   '되다',
#   '?',
#   '어제',
#   '일',
#   '언급',
#   '하다',
#   '?',
#   'ㅋㅋㅋ',
#   '리셋',
#   '임',
#   ','],
#  ['인'],
#  ['8'],
#  ['인'],
#  ['케'],
#  ['인'],
#  ['케'],
#  ['싹둑', '이', '채팅', '창', '관리', '중', '이다'],
#  ['방송', '끄다', '시', '이', '발아'],
#  ['케'],
#  ['오빠', '왜', '아무', '것', '도', '안', '하고', '있샤', '?'],
#  ['인'],
#  ['케'],
#  ['싹둑', '이', '채팅', '창', '관리', '중', '이다'],
#  ['그레인키'],
#  ['인'],
#  ['스트리머', '가', '되어다', '시청자', '보호', '해주다', '덮다', '게', '예의', '아니다'],
#  ['케'],
#  ['인직', '...'],
#  ['미애', '시', '이발', '련'],
#  ['인'],
#  ['싹둑', '이', '채팅', '창', '관리', '중', '이다'],
#  ['케'],
#  ['모르다', '창', '슥', '이', '잘못', '이야'],
#  ['싹둑', '이', '채팅', '창', '관리', '중', '이다'],
#  ['싹둑', '이', '채팅', '창', '관리', '중', '이다'],
#  ['애리조나', '넘버원', '투수', '그레인키'],
#  ['싹둑', '이', '채팅', '창', '관리', '중', '이다'],
#  ['싹둑', '이', '채팅', '창', '관리', '중', '이다'],
#  ['지다'],
#  ['무표정', 'ㅋㅋㅋ'],
#  ['오다', '다', '배다', '버리다'],
#  ['영'],
#  ['?'],
#  ['형', '기', '환', '이', '왓샤'],
#  ['은'],
#  ['싹둑', '이', '채팅', '창', '관리', '중', '이다'],
#  ['?'],
#  ['계속', '그렇게', '해', '보다'],
#  ['싹둑', '이', '채팅', '창', '관리', '중', '이다'],
#  ['노'],
#  ['옥'],
#  ['싹둑', '이', '채팅', '창', '관리', '중', '이다'],
#  ['무'],
#  ['현'],
#  ['와우'],
#  ['요술'],
#  ['옥'],
#  ['가루'],
#  ['뜰'],
#  ['싹둑', '이', '채팅', '창', '관리', '중', '이다'],
#  ['쓰다'],
#  ['싹뚝', '이', '가', '가장', '일', '많이', '하다', '방송', '이다'],
#  ['싹둑', '이', '채팅', '창', '관리', '중', '이다'],
#  ['옥'],
#  ['옥동', '폭슬', '오늘', '도', '시작'],
#  ['뿌리다'],
#  ['줄다'],
#  ['예전',
#   '엔',
#   '아무리',
#   '욕',
#   '들',
#   '어도',
#   '금강',
#   '멘탈',
#   '유지',
#   '하다',
#   '요즘',
#   '돈맛',
#   '을',
#   '보더',
#   '니',
#   '일부러',
#   '화',
#   '내다',
#   '척',
#   '하다',
#   '시청자',
#   '들',
#   '코',
#   '묻다',
#   '돈',
#   '빼앗다',
#   '보다'],
#  ['오빠', '먹방', '하', '샤'],
#  ['E'],
#  ['공산당', '국가', '도', '아니다', '우리', '하다', '왜', '못', '하다', '?'],
#  ['무'],
#  ['빙'],
#  ['무'],
#  ['빙'],
#  ['야', '1', '동', '보', '냐', '?'],
#  ['요술', '요술'],
#  ['머', '하다', 'ㄱㅅㄲ', '야'],
#  ['가루'],
#  ['야', '이', '대머리독수리', '여', 'ㅈㄴ', '늦다'],
#  ['뿌리다'],
#  ['줄다'],
#  ['ㅠ'],
#  ['ㄷㄷㄷ'],
#  ['방송', '꺼', '라', '뒤지다', '싫다'],
#  ['표정', '왜', '이래', '보다', '사람', '불편하다'],
#  ['브베', '형', '아', '기', '환', '이', '오다', '~!'],
#  ['왜', '쓸다', '없다', '?'],
#  ['소', '노'],
#  ['언더테이커', '동생'],
#  ['싹둑', '이', '채팅', '창', '관리', '중', '이다'],
#  ['머', '하다', 'ㅅㅋ'],
#  ['싹둑', '이', '채팅', '창', '관리', '중', '이다'],
#  ['소', '노'],
#  ['싹둑', '이', '채팅', '창', '관리', '중', '이다'],
#  ['ㅋㅋㅋ'],
#  ['생방', '처음', '온당'],
#  ['니', '도', '쓸데없다', '하자', '나', '?'],
#  ['요술', '가루'],
#  ['브베', '피융', '신', '새끼'],
#  ['아니다', '아무', '것', '도', '못', '하다', '하다', '방송왜켯', '냐'],
#  ['어허'],
#  ['ㅋㅋㅋ', '이제', '건', '.', '물', '도', '있다', '배', '째', '는', '거', '냐'],
#  ['왜늦엇냐'],
#  ['쁘려즈세', '요'],
#  ['매', '너', '채팅', '해', '라'],
#  ['핑', '쉰', '브베'],
#  ['싹둑', '이', '채팅', '창', '관리', '중', '이다'],
#  ['쑬데엄눈말', '하', '쥐다', '~'],
#  ['시청자', '한테', '그따위', '로', '말', '하다', '방종하다'],
#  ['지금', '왜', '소', '노', '?'],
#  ['쓸데없다', '방송', '이', '니깐', '쓸데없다', '말다', '~'],
#  ['본격', '수금', '방송'],
#  ['브베핑쉰', '이다'],
#  ['무슨', '말', '?', '소통', '좀', '하다'],
#  ['안넝', '하다'],
#  ['브베', '뚝', '베다', '3', '렙'],
#  ['핑', '쉰', '브베'],
#  ['이르다', '브베', '형', '나쁘다', '마음', '먹다', '어떻다', '.'],
#  ['우', '가다', '방송', '접다', '하다', '않다', '?'],
#  ['시작',
#   '하',
#   '자마자',
#   '화',
#   '내',
#   '려면',
#   '방송',
#   '집다',
#   '치다',
#   'ㅆㅂ',
#   '시작',
#   '하',
#   '자마자',
#   '화',
#   '내',
#   '려면',
#   '방송',
#   '집다',
#   '치다',
#   'ㅆㅂ',
#   '시작',
#   '하',
#   '자마자',
#   '화',
#   '내',
#   '려면',
#   '방송',
#   '집다',
#   '치다',
#   'ㅆㅂ',
#   '시작',
#   '하',
#   '자마자',
#   '화',
#   '내',
#   '려면',
#   '방송',
#   '집다',
#   '치다',
#   'ㅆㅂ'],
#  ['시청자', '를', '위', '한', '방송', '아니다', '수금', '방송', '이다'],
#  ['싹둑', '이', '채팅', '창', '관리', '중', '이다'],
#  ['브베', '형', '기', '환', '이', '오다', '인사', '해주다', '샤'],
#  ['저', '거', '이제', '1000원', '가다', '그라샤', '도', '안', '해주다'],
#  ['노래', '다르다', '좀', '틀어주다'],
#  ['형', '어제', '부르다', '노래', '뭐', '야'],
#  ['노래', '딱', '조', '오타', '~!'],
#  ['주둥이', '가', '왜', '이렇게', '튀어', '나오다', '엉', '?', '굴비', '야', '?'],
#  ['싹둑', '이', '채팅', '창', '관리', '중', '이다'],
#  ['방송', '왜켯', '냐', '이색기'],
#  ['배', '가', '처불렀스'],
#  ['픵씐', '아', '~'],
#  ['싹둑', '이', '채팅', '창', '관리', '중', '이다'],
#  ['옥', '뜨다', '리', '한테', '사과', '하다'],
#  ['브베', '한테', '늘다', '이제', '우리', '밖에', '없다'],
#  ['싹둑', '이', '채팅', '창', '관리', '중', '이다'],
#  ['금칙어', '추가', '하다', '손', '놀림', '아주', '바쁘다'],
#  ['이', '새끼', '오', '자마자', '왜', '입', '삐쭉', '내', '밀고', '있다', '?'],
#  ['가비', 'Bro', '~~~'],
#  ['오늘', '은', '10만원', '이내', '로', '끊다'],
#  ['입', '삐죽다'],
#  ['ㄴㄷ'],
#  ['브베', '너무', '놀리다', '후원', '해주다'],
#  ['싹둑', '이', '채팅', '창', '관리', '중', '이다'],
#  ['이샊', '왜', '안', '오다', '??'],
#  ['브베', '형', '잘생겻샤', '!!'],
#  ['입', '삐죽다', '너', '온', '거', '보다', '오다', '따다', '~'],
#  ['건물', '에', '깔다', '뒤지다'],
#  ['뭐라다', '도해', '라', '노잼', '이다'],
#  ['도넛', '안', '터지다', '입', '튀어나오다', '임', '?'],
#  ['싹둑', '이', '채팅', '창', '관리', '중', '이다'],
#  ['가비', '브로', 'ke', 'in'],
#  ['싹둑', '이', '채팅', '창', '관리', '중', '이다'],
#  ['ㄱㅅㄲ', '야'],
#  ['씨발', '럼', '이'],
#  ['옥', '슬', '아'],
#  ['형', '어제', '부르다', '노래', '제목', '뭐', '야'],
#  ['이', '새끼', '왜', '안오냑', 'ㅎ'],
#  ['브베', '배', '뽱뽱', '퍼퍼퍼펃'],
#  ['시', '이발', '브베', '개', '새', '애끼', '야', '방송', '안', '끄다'],
#  ['핑쉰'],
#  ['지랄', '하다'],
#  ['브베', '형', '오늘', '은', '퍤티', '입다', '??', '안', '입다', '??', 'ㅎㅎㅎ'],
#  ['왠', '일로', '소통', '을', '?'],
#  ['브베', '야', '형', '오다', '인사', '해보다'],
#  ['눈빛', '살벌하다'],
#  ['형', '어제', '부르다', '노래', '뭐', '냐', '궁'],
#  ['브베',
#   '님',
#   '이',
#   '쓸다',
#   '마이크',
#   '는',
#   '직접',
#   '개조',
#   '한',
#   '건가',
#   '왜',
#   '듣다',
#   '부분',
#   '이',
#   '없다',
#   '?'],
#  ['싹둑', '이', '채팅', '창', '관리', '중', '이다'],
#  ['언더테이커', '동생'],
#  ['브베', '배', '펑펑', '터트려', '아주'],
#  ['싹둑', '이', '채팅', '창', '관리', '중', '이다'],
#  ['그만하다', '임마'],
#  ['오늘', '미애', '가', '말대꾸', '함', '?', '표정', '왜', '저렇다'],
#  ['브베', '님', '10만원', '에', '모자', '벗기다', '.'],
#  ['재밌다', '좀', '하샤'],
#  ['싹둑', '이', '채팅', '창', '관리', '중', '이다'],
#  ['오늘', '레베카', '결근', '이라고', '하다'],
#  ['게임', '하다'],
#  ['싹둑', '이', '채팅', '창', '관리', '중', '이다'],
#  ['억', '아'],
#  ['ㅣ', '.'],
#  ['겜', 'ㄱㄱ'],
#  ['개띠껍', '게', '말', '하다'],
#  ['브베', '님', '오른쪽', '이', '컴퓨터', '같다', '뭔가', '요', 'ㅎㅎ'],
#  ['억', '슬', '앙'],
#  ['말투', '보다', '시발', '럼'],
#  ['사과', '하', '랬다', '고', '베다', '먹이다', '욕', '도', '알다', '?'],
#  ['ke', 'on'],
#  ['형', '어제', '부르다', '노래', '제목', '뭐', '냐', '고'],
#  ['도넛', '안', '터지다', '하다', '없다'],
#  ['슬', '아'],
#  ['미애', '시', '이발']]

# %%
# load vocab
with open('./vocab/vocab_index.pickle', 'rb') as f:
    vocab_index = pickle.load(f)
with open('./vocab/vocab_inverted_index.pickle', 'rb') as f:
    vocab_inverted_index = pickle.load(f)

# %%
def index_to_text(indexes):
    return ' '.join([word_inverted_index[i] for i in indexes])

def text_to_index(tokens):
    oov_id = 1
    indexes = []
    for tok in tokens:
        if tok in vocab_index:
            indexes.append(vocab_index[tok])
        else:
            indexes.append(oov_id)

    return indexes

# %%
pad_id = 0

x_variable = [text_to_index(_) for _ in morped]

sentence_size = 20
x_padded = sequence.pad_sequences(x_variable,
                                 maxlen=sentence_size,
                                 truncating='post',
                                 padding='post',
                                 value=pad_id)

# %% [markdown]
# # Load Model

# %%
new_model = keras.models.load_model('../model/cnn_oversample.h5')
new_model.summary()
# Out:
# WARNING:tensorflow:From C:\Users\skarn\Anaconda3\envs\DataAnalysis\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From C:\Users\skarn\Anaconda3\envs\DataAnalysis\lib\site-packages\tensorflow\python\keras\layers\core.py:143: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From C:\Users\skarn\Anaconda3\envs\DataAnalysis\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From C:\Users\skarn\Anaconda3\envs\DataAnalysis\lib\site-packages\tensorflow\python\ops\math_grad.py:102: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_9 (Embedding)      (None, None, 10)          80000
# _________________________________________________________________
# conv1d_21 (Conv1D)           (None, None, 32)          992
# _________________________________________________________________
# dropout_17 (Dropout)         (None, None, 32)          0
# _________________________________________________________________
# conv1d_22 (Conv1D)           (None, None, 32)          3104
# _________________________________________________________________
# global_max_pooling1d_10 (Glo (None, 32)                0
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_9 (Dense)              (None, 2)                 66
# =================================================================
# Total params: 84,162
# Trainable params: 84,162
# Non-trainable params: 0
# _________________________________________________________________

# %%
dump_data['predict'] = new_model.predict_classes(x_padded)

# %%
new_model.evaluate(x_padded, pd.get_dummies(dump_data.label)) # loss, acc
# Out:
# 500/500 [==============================] - ETA: 6s - loss: 0.0646 - recall_16: 1.000 - 1s 1ms/sample - loss: 0.6722 - recall_16: 0.8820
# [0.6721757929325104, 0.882]

# %% [markdown]
# #### 전체 채팅 중 유해채팅 비율

# %%
dump_data.predict.sum() / len(dump_data)
# Out:
# 0.084

# %% [markdown]
# > 5%가 적당하다
